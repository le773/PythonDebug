# %%
import tensorflow as tf
from numpy.random import RandomState
#### 1. 定义神经网络的参数，输入和输出节点。
batch_size = 8
w1= tf.Variable(tf.random_normal([2, 3], stddev=1, seed=1))
w2= tf.Variable(tf.random_normal([3, 1], stddev=1, seed=1))


x = tf.placeholder(tf.float32, shape=(None, 2), name='x-input')
y_= tf.placeholder(tf.float32, shape=(None, 1), name='y-input')



#### 2. 定义前向传播过程，损失函数及反向传播算法。"
a = tf.matmul(x, w1)
y = tf.matmul(a, w2)

cross_entropy = -tf.reduce_mean(y_ * tf.log(tf.clip_by_value(y, 1e-10, 1.0)))
train_step = tf.train.AdamOptimizer(0.001).minimize(cross_entropy)

####  3. 生成模拟数据集。
rdm = RandomState(1)
X = rdm.rand(128,2)
Y = [[int(x1+x2 < 1)] for (x1, x2) in X]

#### 4. 创建一个会话来运行TensorFlow程序。
with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    print ("w1:", sess.run(w1))
    print ("w2:", sess.run(w2))
    STEPS = 5000
    for i in range(STEPS):
        start = (i*batch_size) % 128
        end = (i*batch_size) % 128 + batch_size
        sess.run(train_step, feed_dict={x: X[start:end], y_: Y[start:end]})
        if i % 1000 == 0:
            total_cross_entropy = sess.run(cross_entropy, feed_dict={x: X, y_: Y})
            print("After %d training step(s), cross entropy on all data is %g" % (i, total_cross_entropy))

        # 输出训练后的参数取值。
        print("\n")
        print("w1:", sess.run(w1))
        print("w2:", sess.run(w2))
# Out:
# w1: [[-0.8113182   1.4845988   0.06532937]
#  [-2.4427042   0.0992484   0.5912243 ]]
# w2: [[-0.8113182 ]
#  [ 1.4845988 ]
#  [ 0.06532937]]
# After 0 training step(s), cross entropy on all data is 0.0674925
#
#
# w1: [[-0.8123182   1.4855988   0.06632921]
#  [-2.4437041   0.1002484   0.59222424]]
# w2: [[-0.8123182 ]
#  [ 1.4855988 ]
#  [ 0.06632937]]
#
#
# w1: [[-0.8132937   1.4865743   0.06730329]
#  [-2.4446583   0.1012025   0.59318024]]
# w2: [[-0.8132974 ]
#  [ 1.4865836 ]
#  [ 0.06729427]]
#
#
# w1: [[-0.81404775  1.4873284   0.06805624]
#  [-2.445396    0.10194003  0.5939192 ]]
# w2: [[-0.8140543 ]
#  [ 1.4873449 ]
#  [ 0.06804014]]
#
#
# w1: [[-0.81466544  1.4879462   0.06867302]
#  [-2.446       0.10254417  0.59452456]]
# w2: [[-0.8146743 ]
#  [ 1.4879684 ]
#  [ 0.06865111]]
#
#
# w1: [[-0.8151875   1.4884683   0.06919434]
#  [-2.4465108   0.1030548   0.5950362 ]]
# w2: [[-0.81519836]
#  [ 1.4884955 ]
#  [ 0.06916752]]
#
#
# w1: [[-0.81563747  1.4889183   0.06964365]
# ...

# %%
cross_entropy = -tf.reduce_mean(y_ * tf.log(tf.clip_by_value(y, 1e-10, 1.0)))
learning_rate = 0.001
train_step = tf.train.AdamOptimizer(learing_rete).minimize(cross_entropy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-73d04edb9fb8> in <module>()
#       1 cross_entropy = -tf.reduce_mean(y_ * tf.log(tf.clip_by_value(y, 1e-10, 1.0)))
#       2 learning_rate = 0.001
# ----> 3 train_step = tf.train.AdamOptimizer(learing_rete).minimize(cross_entropy)
#
# NameError: name 'learing_rete' is not defined

# %%
import tensorflow as tf

# Create TensorFlow object called tensor
hello_constant = tf.constant('Hello World!')

with tf.Session() as sess:
    # Run the tf.constant operation in the session
    output = sess.run(hello_constant)
    print(output)
    A = tf.constant(1234)
    print(sess.run(A))
    print(sess.run(tf.constant([123,456,789])))

# %%
x1 = tf.add(5,2)
print(x1.shape)

# %%
a = tf.constant([1.0, 2.0])
b = tf.constant([2.0, 3.0])
result = a + b
print(a.graph is tf.get_default_graph())

# %%
print(a.graph)

# %%
gl = tf.Graph()
with gl.as_default():
    v = tf.get_variable("v", shape=[1], initializer=tf.zeros_initializer)
    print(v)

# %%
tf.GraphKeys.VARIABLES

# %%
tf.GraphKeys.GLOBAL_VARIABLES

# %%
tf.GraphKeys.QUEUE_RUNNERS

# %%
tf.Variable

# %%
# declare 2 * 3 matrix
weights = tf.Variable(tf.random_normal([2,3],stddev=2))
weights

# %%
biases = tf.Variable(tf.zeros([3]))

# %%
w2 = tf.Variable(weights.initialized_value())
w2

# %%
w3 = tf.Variable(weights.initialized_value() * 2.0)
w3

# %%
sess = tf.Session()
w4 = tf.Variable(tf.random_normal([2,3],stddev=2, seed=1))
w5 = tf.Variable(tf.random_normal([3,1],stddev=1, seed=1))
x2 = tf.constant([[0.7,0.9]])
a = tf.matmul(x2, w4)
y = tf.matmul(a, w5)
sess.run(w4.initializer)
sess.run(w5.initializer)
print(w4)
print(w5)
print(sess.run(y))

# %%
init_op = tf.initialize_all_variables() # 自动处理变量间的依赖关系
print(sess.run(init_op))

# %%
tf.GraphKeys.TRAINABLE_VARIABLES # TRAINABLE_VARIABLES中的变量作为默认优化对象

# %%
tf.trainable_variables #所有需要优化的参数

# %%
sess = tf.Session()
w5 = tf.Variable(tf.random_normal([2,3],stddev=1))
w6 = tf.Variable(tf.random_normal([3,1],stddev=1))
x3 = tf.placeholder(tf.float32, shape=(1,2), name='input')
x4 = tf.matmul(x3, w5)
y = tf.matmul(x4, w6)
init_op = tf.initialize_all_variables()
sess.run(init_op)
print(sess.run(y, feed_dict={x3:[[0.7,0.9]]}))
# Out:
# [[-4.1698127]]

# %%
sess = tf.Session()
w5 = tf.Variable(tf.random_normal([2,3],stddev=1))
w6 = tf.Variable(tf.random_normal([3,1],stddev=1))
x3 = tf.placeholder(tf.float32, shape=(3,2), name='input')
x4 = tf.matmul(x3, w5)
y = tf.matmul(x4, w6)
init_op = tf.initialize_all_variables()
sess.run(init_op)
print(sess.run(y, feed_dict={x3:[[0.7,0.9],[0.1,0.4],[0.5,0.8]]}))
# Out:
# [[-2.13708  ]
#  [-0.2192412]
#  [-1.4766638]]

# %%
tf.log(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-c611412576f3> in <module>()
# ----> 1 tf.log(10)
#
# E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in log(x, name)
#    2608   if _ctx.in_graph_mode():
#    2609     _, _, _op = _op_def_lib._apply_op_helper(
# -> 2610         "Log", x=x, name=name)
#    2611     _result = _op.outputs[:]
#    2612     _inputs_flat = _op.inputs
#
# E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     607               _SatisfiesTypeConstraint(base_type,
#     608                                        _Attr(op_def, input_arg.type_attr),
# --> 609                                        param_name=input_name)
#     610             attrs[input_arg.type_attr] = attr_value
# ...

# %%
print(tf.reduce_sum([1,2]))
# Out:
# Tensor("Sum_1:0", shape=(), dtype=int32)

# %%
print(tf.log(16))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-7f6eae72a316> in <module>()
# ----> 1 print(tf.log(16))
#
# E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in log(x, name)
#    2608   if _ctx.in_graph_mode():
#    2609     _, _, _op = _op_def_lib._apply_op_helper(
# -> 2610         "Log", x=x, name=name)
#    2611     _result = _op.outputs[:]
#    2612     _inputs_flat = _op.inputs
#
# E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     607               _SatisfiesTypeConstraint(base_type,
#     608                                        _Attr(op_def, input_arg.type_attr),
# --> 609                                        param_name=input_name)
#     610             attrs[input_arg.type_attr] = attr_value
# ...

# %%
tf.log(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3e39c5a79cdc> in <module>()
# ----> 1 tf.log(100)
#
# E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in log(x, name)
#    2608   if _ctx.in_graph_mode():
#    2609     _, _, _op = _op_def_lib._apply_op_helper(
# -> 2610         "Log", x=x, name=name)
#    2611     _result = _op.outputs[:]
#    2612     _inputs_flat = _op.inputs
#
# E:\Anaconda3\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     607               _SatisfiesTypeConstraint(base_type,
#     608                                        _Attr(op_def, input_arg.type_attr),
# --> 609                                        param_name=input_name)
#     610             attrs[input_arg.type_attr] = attr_value
# ...

# %%
# Out:
# Weights:
# [[-1.3336271  -0.09045336 -0.17338656]
#  [-0.5119246  -0.22988157 -0.56073236]]
# Bias:
# [-0.78012824  1.0783366   0.52476186]
